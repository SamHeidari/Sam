# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns
from scipy.stats import ttest_ind

# Cause plots to be displayed in the notebook:
# %pylab inline
# %matplotlib inline
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\samhe\OneDrive\Documents\iod\project 1

# %%
salary = pd.read_csv('C:\\Users\\samhe\\OneDrive\\Documents\\iod\\Data Folder\\Salary_Data.csv')

# %%
salary.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
salary.tail()
# Out:
#        Age  Gender    Education Level              Job Title  \
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 6699                 20.0  200000.0
# 6700                  3.0   50000.0
# 6701                  4.0   55000.0
# 6702                 14.0  140000.0
# 6703                  1.0   35000.0

# %%
salary.shape
# Out:
# (6704, 6)

# %%
salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6704 entries, 0 to 6703
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  6702 non-null   float64
#  1   Gender               6702 non-null   object
#  2   Education Level      6701 non-null   object
#  3   Job Title            6702 non-null   object
#  4   Years of Experience  6701 non-null   float64
#  5   Salary               6699 non-null   float64
# dtypes: float64(3), object(3)
# memory usage: 314.4+ KB

# %%
salary.columns = salary.columns.str.replace(' ','_').str.lower().str.strip()

# %%
salary.head()
# Out:
#     age  gender education_level          job_title  years_of_experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
salary.dtypes
# Out:
# age                    float64
# gender                  object
# education_level         object
# job_title               object
# years_of_experience    float64
# salary                 float64
# dtype: object

# %%
salary['age'].unique()
# Out:
# array([32., 28., 45., 36., 52., 29., 42., 31., 26., 38., 48., 35., 40.,
#        27., 44., 33., 39., 25., 51., 34., 47., 30., 41., 37., 24., 43.,
#        50., 46., 49., 23., 53., nan, 61., 57., 62., 55., 56., 54., 60.,
#        58., 22., 21.])

# %%
salary['education_level'].unique()
# Out:
# array(["Bachelor's", "Master's", 'PhD', nan, "Bachelor's Degree",
#        "Master's Degree", 'High School', 'phD'], dtype=object)

# %%
salary['education_level'].value_counts().sort_values()
# Out:
# education_level
# phD                     1
# Master's              288
# High School           448
# Bachelor's            756
# PhD                  1368
# Master's Degree      1573
# Bachelor's Degree    2267
# Name: count, dtype: int64

# %%
salary[salary.age.isna()]
# Out:
#      age gender education_level job_title  years_of_experience  salary
# 172  NaN    NaN             NaN       NaN                  NaN     NaN
# 260  NaN    NaN             NaN       NaN                  NaN     NaN

# %%
salary[salary.salary.isna()]
# Out:
#        age  gender    education_level            job_title  \
# 172    NaN     NaN                NaN                  NaN
# 260    NaN     NaN                NaN                  NaN
# 3136  31.0    Male    Master's Degree  Full Stack Engineer
# 5247  26.0  Female  Bachelor's Degree             Social M
# 6455  36.0    Male  Bachelor's Degree       Sales Director
#
#       years_of_experience  salary
# 172                   NaN     NaN
# 260                   NaN     NaN
# 3136                  8.0     NaN
# 5247                  NaN     NaN
# 6455                  6.0     NaN

# %%
salary.drop([172,260,3136,5247,6455], inplace = True)

# %%
salary[salary.salary.isna()]
# Out:
# Empty DataFrame
# Columns: [age, gender, education_level, job_title, years_of_experience, salary]
# Index: []

# %%
salary[salary.age.isna()]
# Out:
# Empty DataFrame
# Columns: [age, gender, education_level, job_title, years_of_experience, salary]
# Index: []

# %%
salary['age'].astype('int')
# Out:
# 0       32
# 1       28
# 2       45
# 3       36
# 4       52
#         ..
# 6699    49
# 6700    32
# 6701    30
# 6702    46
# 6703    26
# Name: age, Length: 6699, dtype: int32

# %%
salary['gender'].unique()
# Out:
# array(['Male', 'Female', nan, 'Other'], dtype=object)

# %%
salary['gender'].value_counts()
# Out:
# gender
# Male      3674
# Female    3014
# Other       14
# Name: count, dtype: int64

# %%
salary.isnull().sum()
# Out:
# age                    0
# gender                 0
# education_level        1
# job_title              0
# years_of_experience    0
# salary                 0
# dtype: int64

# %%
salary.hist(figsize=(15,10))
# Out:
# array([[<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'years_of_experience'}>],
#        [<Axes: title={'center': 'salary'}>, <Axes: >]], dtype=object)

# %%
sns.histplot(salary, x = salary.salary)
# Out:
# C:\Users\samhe\anaconda3\envs\iod\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\samhe\anaconda3\envs\iod\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='salary', ylabel='Count'>

# %%
sns.histplot(salary, x = salary.gender)
# Out:
# C:\Users\samhe\anaconda3\envs\iod\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\samhe\anaconda3\envs\iod\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\samhe\anaconda3\envs\iod\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='gender', ylabel='Count'>

# %%
sns.barplot(x='education_level',y='salary', data = salary)
plt.title('');
# Out:
# C:\Users\samhe\anaconda3\envs\iod\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\samhe\anaconda3\envs\iod\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\samhe\anaconda3\envs\iod\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
sns.barplot(x='gender',y='salary', data = salary)
plt.title('');
# Out:
# C:\Users\samhe\anaconda3\envs\iod\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\samhe\anaconda3\envs\iod\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\samhe\anaconda3\envs\iod\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
salary[salary['gender']=='Other']
# Out:
#        age gender  education_level                 job_title  \
# 2378  53.0  Other      High School   Senior Project Engineer
# 2385  25.0  Other      High School       Full Stack Engineer
# 2406  37.0  Other  Master's Degree       Full Stack Engineer
# 2448  31.0  Other      High School        Back end Developer
# 2454  23.0  Other      High School       Front end Developer
# 2458  53.0  Other      High School   Senior Project Engineer
# 2465  25.0  Other      High School       Full Stack Engineer
# 2486  37.0  Other  Master's Degree       Full Stack Engineer
# 2528  31.0  Other      High School        Back end Developer
# 2534  23.0  Other      High School       Front end Developer
# 2554  54.0  Other      High School  Senior Software Engineer
# 2800  54.0  Other      High School  Senior Software Engineer
# 2919  54.0  Other      High School  Senior Software Engineer
# 3038  54.0  Other      High School  Senior Software Engineer
#
#       years_of_experience    salary
# ...

# %%
genders = salary['gender'].value_counts()
plt.pie(genders, autopct='%1.1f%%', labels=genders.index)
plt.show()

# %%
salary['gender'].value_counts()
# Out:
# gender
# Male      3672
# Female    3013
# Other       14
# Name: count, dtype: int64

# %%
salary['age'].mean()
# Out:
# 33.62203313927452

# %%
salary[salary['gender']=='Female']['age'].mean()
# Out:
# 32.62628609359442

# %%
salary[salary['gender']=='Female']['salary'].mean()
# Out:
# 107888.99867241952

# %%
salary[salary['gender']=='Male']['age'].mean()
# Out:
# 34.41639433551198

# %%
salary[salary['gender']=='Male']['salary'].mean()
# Out:
# 121389.87091503268

# %%
plt.scatter(salary.gender,salary.salary)

# %%
y = salary.salary
y
# Out:
# 0        90000.0
# 1        65000.0
# 2       150000.0
# 3        60000.0
# 4       200000.0
#           ...
# 6699    200000.0
# 6700     50000.0
# 6701     55000.0
# 6702    140000.0
# 6703     35000.0
# Name: salary, Length: 6704, dtype: float64

# %%
male_salary = salary[salary['gender']=='Male'].salary.mean()
male_salary
# Out:
# 121389.87091503268

# %%
Female_salary = salary[salary['gender']=='Female'].salary.mean()
Female_salary
# Out:
# 107888.99867241952

# %%
ax = male_salary.plot(kind = 'bar', stacked = True, figsize=(10,5))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 ax = male_salary.plot(kind = 'bar', stacked = True, figsize=(10,5))
#       2 plt.show()
#
# AttributeError: 'numpy.float64' object has no attribute 'plot'

# %%
grouped_data = salary.groupby(['gender','salary']).size().unstack()
ax = grouped_data.plot(kind = 'bar',stacked = True,figsize=(10,6))
plt.show()

# %%
salary.salary
# Out:
# 0        90000.0
# 1        65000.0
# 2       150000.0
# 3        60000.0
# 4       200000.0
#           ...
# 6699    200000.0
# 6700     50000.0
# 6701     55000.0
# 6702    140000.0
# 6703     35000.0
# Name: salary, Length: 6704, dtype: float64

# %%
alpha = 0.05

# %%
male_salaries = salary[salary['gender']=='Male']['salary']
female_salaries = salary[salary['gender']=='Female']['salary']

# %%
ax = sns.distplot(male_salaries, label='male_salaries', kde=False);
sns.distplot(female_salaries, ax= ax, label='female_salaries', kde=False);
plt.legend(loc = 'upper right')
plt.xlabel('')
plt.ylabel('')
plt.show();
# Out:
# C:\Users\samhe\AppData\Local\Temp\ipykernel_16496\605099470.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(male_salaries, label='male_salaries', kde=False);
# C:\Users\samhe\AppData\Local\Temp\ipykernel_16496\605099470.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...
